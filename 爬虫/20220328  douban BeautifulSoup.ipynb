# %%
import requests
from bs4 import BeautifulSoup
import csv
url_list=[]
num_temp= 0
headers={
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36"
}
f = open("豆瓣TOP250.csv",mode="w",encoding="utf-8")
csvwriter =csv.writer(f)
while num_temp<250:
    url='https://movie.douban.com/top250?start='+ str(num_temp)+'&filter='
    url_list.append(url)
    num_temp=num_temp+25
for url_temp in url_list:
    resp=requests.get(url_temp,headers=headers)
    page=BeautifulSoup(resp.text,"html.parser")#指定HTML解析
    movie_list = page.find_all('ol',attrs={"class":"grid_view"})
    for i in movie_list[0].find_all('li'):
        try:
            num=i.find('em',class_="""""").text
            name=i.find('span',class_="title").text
            score=i.find('span',class_="rating_num").text
            main=i.find('p',class_="quote").text
            link=i.find('a')['href']
        except(AttributeError):
            review=' \n\n'
        csvwriter.writerow(['序号:'+num+'\n电影名：'+name+'\n评分：'+score +'\n推荐语：'+main +'电影链接 '+link])
f.close()
print("over!")
#从BS对象中查找数据 find(标签，属性=值)  find_all (标签，属性=值)
#table=page.find("table",class_="hq_table") 一样

#print(movie_list)
# Out:
# over!

# %%
import requests
from bs4 import BeautifulSoup
import csv
url_list=[]
num_temp= 0
headers={
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36"
}


while num_temp<250:
    url='https://movie.douban.com/top250?start='+ str(num_temp)+'&filter='
    url_list.append(url)
    num_temp=num_temp+25
for url_temp in url_list:
    resp=requests.get(url_temp,headers=headers)
    page=BeautifulSoup(resp.text,"html.parser")#指定HTML解析
    movie_list = page.find_all('ol',attrs={"class":"grid_view"})
    for i in movie_list[0].find_all('li'):
        try:
            num=i.find('em',class_="""""").text
            name=i.find('span',class_="title").text
            score=i.find('span',class_="rating_num").text
            main=i.find('p',class_="quote").text
            link=i.find('a')['href']
        except(AttributeError):
            review=' \n\n'
        print('序号:'+num+'\n电影名：'+name+'\n评分：'+score +'\n推荐语：'+main +'电影链接 '+link)

print("over!")
#从BS对象中查找数据 find(标签，属性=值)  find_all (标签，属性=值)
#table=page.find("table",class_="hq_table") 一样

#print(movie_list)
# Out:
# 序号:1
# 电影名：肖申克的救赎
# 评分：9.7
# 推荐语：
# 希望让人自由。
# 电影链接 https://movie.douban.com/subject/1292052/
# 序号:2
# 电影名：霸王别姬
# 评分：9.6
# 推荐语：
# 风华绝代。
# 电影链接 https://movie.douban.com/subject/1291546/
# 序号:3
# 电影名：阿甘正传
# 评分：9.5
# 推荐语：
# 一部美国近现代史。
# 电影链接 https://movie.douban.com/subject/1292720/
# 序号:4
# 电影名：泰坦尼克号
# 评分：9.4
# 推荐语：
# 失去的才是永恒的。
# 电影链接 https://movie.douban.com/subject/1292722/
# 序号:5
# 电影名：这个杀手不太冷
# 评分：9.4
# 推荐语：
# 怪蜀黍和小萝莉不得不说的故事。
# 电影链接 https://movie.douban.com/subject/1295644/
# 序号:6
# 电影名：美丽人生
# 评分：9.6
# 推荐语：
# 最美的谎言。
# 电影链接 https://movie.douban.com/subject/1292063/
# 序号:7
# 电影名：千与千寻
# 评分：9.4
# 推荐语：
# 最好的宫崎骏，最好的久石让。
# 电影链接 https://movie.douban.com/subject/1291561/
# 序号:8
# 电影名：辛德勒的名单
# 评分：9.6
# 推荐语：
# 拯救一个人，就是拯救整个世界。
# 电影链接 https://movie.douban.com/subject/1295124/
# 序号:9
# 电影名：盗梦空间
# 评分：9.4
# 推荐语：
# 诺兰给了我们一场无法盗取的梦。
# 电影链接 https://movie.douban.com/subject/3541415/
# 序号:10
# 电影名：忠犬八公的故事
# 评分：9.4
# 推荐语：
# 永远都不能忘记你所爱的人。
# 电影链接 https://movie.douban.com/subject/3011091/
# 序号:11
# 电影名：星际穿越
# ...
